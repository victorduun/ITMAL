# %% [markdown]
# # Opgave a og b)

# %%
# %reset -f
from sklearn.neural_network import MLPRegressor
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-3,3,1000)
y = np.sinc(X)

X = X.reshape(-1,1) # Scikit-algoritmer kræver (:,1)-format

mlp = MLPRegressor(activation = 'tanh', # aktiveringsfunktion
                   hidden_layer_sizes = 2, # antal skjulte neuroner
                   alpha = 1e-5, # regulariseringsparameter, her meget lille
                   solver = 'lbfgs', # quasi-Newton solver
                   max_iter=1000,
                   verbose = True)

mlp.fit(X,y)
y_pred = mlp.predict(X)
plt.plot(X,y)
plt.plot(X,y_pred)

print(f"Bias: {mlp.intercepts_}")
print(f"Weights: {mlp.coefs_}")
# Out:
# Bias: [array([ 2.16973765, -2.21311251]), array([-0.02856674])]
# Weights: [array([[3.54642513, 3.61912557]]), array([[ 0.50592321],
#        [-0.50559916]])]

# %% [markdown]
# # Opgave c og d)

# %%
# %reset -f
from sklearn.neural_network import MLPRegressor
import numpy as np
import matplotlib.pyplot as plt


def neural_network_func(x, coefs, intercepts, learning_rate):
    w_0_0 = coefs[0][0,0]
    w_0_1 = coefs[0][0,1]
    #
    w_1_0 = coefs[1][0,0]
    w_1_1 = coefs[1][1,0]
    #
    b_0_0 = intercepts[0][0]
    b_0_1 = intercepts[0][1]
    #
    b_1_0 = intercepts[1][0]
    #
    a_1 = learning_rate*np.tanh(w_0_0*x+b_0_0)
    a_2 = learning_rate*np.tanh(w_0_1*x+b_0_1)
    #
    #
    o_1 = b_1_0+w_1_0*a_1+w_1_1*a_2
    # Tal fra opg. A, B
    # a_1 = 0.001*np.tanh(3.623*x+-2.216)
    # a_2 = 0.001*np.tanh(-3.546*x+-2.173)
    # o_1 = -0.026+-0.505*a_1+-0.506*a_2

    #o_1 = learning_rate*np.tanh((-0.026-0.505)*(-2.216+3.623*x)) + learning_rate*np.tanh(-2.173-3.546*x)

    return o_1

X = np.linspace(-3,3,1000)
y = np.sinc(X)

X = X.reshape(-1,1) # Scikit-algoritmer kræver (:,1)-format

mlp = MLPRegressor(activation = 'tanh', # aktiveringsfunktion
                   hidden_layer_sizes = 2, # antal skjulte neuroner
                   alpha = 1e-5, # regulariseringsparameter, her meget lille
                   solver = 'lbfgs', # quasi-Newton solver
                   max_iter=1000,
                   verbose = True)
mlp.fit(X,y)


y_pred = neural_network_func(X,mlp.coefs_,mlp.intercepts_,mlp.learning_rate_init)

#Test
y_pred2 = mlp.predict(X)

plt.plot(X,y_pred)
#plt.plot(X,y_pred2)

# %%
# Opgave e)

# %%
# %reset -f
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-3,3,1000)
y = np.sinc(X)

X = X.reshape(-1,1) # Scikit-algoritmer kræver (:,1)-format

a_1 = 0.001*np.tanh(3.623*X+-2.216)
a_2 = 0.001*np.tanh(-3.546*X+-2.173)

plt.plot(X,a_1)
plt.plot(X,a_2)

# %%
# Opgave f)

# %%
# %reset -f
from sklearn.neural_network import MLPRegressor
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-3,3,1000)
y = np.sinc(X)

X = X.reshape(-1,1) # Scikit-algoritmer kræver (:,1)-format

mlp = MLPRegressor(activation = 'tanh', # aktiveringsfunktion
                   hidden_layer_sizes = 5, # antal skjulte neuroner
                   alpha = 1e-5, # regulariseringsparameter, her meget lille
                   solver = 'lbfgs', # quasi-Newton solver
                   max_iter=1000,
                   verbose = True)

mlp.fit(X,y)
y_pred = mlp.predict(X)
plt.plot(X,y)
plt.plot(X,y_pred)

print(f"Bias: {mlp.intercepts_}")
print(f"Weights: {mlp.coefs_}")
# Out:
# Bias: [array([ 0.98612362, -2.18414993, -4.48129465, -0.81304476, -0.82404264]), array([-0.46573492])]
# Weights: [array([[-0.71071727,  0.74431868, -2.57523049, -1.42429975,  1.0983031 ]]), array([[-3.38866382],
#        [-1.64927803],
#        [ 0.3212959 ],
#        [-1.04653012],
#        [-3.00400728]])]

# %%
# Opgave g

# %%
# %reset -f
from sklearn.neural_network import MLPRegressor
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-3,3,1000)
y = np.sinc(X)

X = X.reshape(-1,1) # Scikit-algoritmer kræver (:,1)-format

mlp = MLPRegressor(activation = 'tanh', # aktiveringsfunktion
                   hidden_layer_sizes = 5, # antal skjulte neuroner
                   alpha = 1e-1, # regulariseringsparameter, her meget lille
                   solver = 'lbfgs', # quasi-Newton solver
                   max_iter=1000,
                   verbose = True)

mlp.fit(X,y)
y_pred = mlp.predict(X)
plt.plot(X,y)
plt.plot(X,y_pred)

print(f"Bias: {mlp.intercepts_}")
print(f"Weights: {mlp.coefs_}")
# Out:
# Bias: [array([-2.82517752, -0.38633172,  0.58278016,  0.06303583, -1.52838266]), array([0.0557224])]
# Weights: [array([[-1.64020257,  1.84347389,  0.69722885, -0.67060332,  2.00579138]]), array([[ 0.89558709],
#        [-0.7964046 ],
#        [ 1.38365985],
#        [-1.45472403],
#        [-0.99154825]])]
