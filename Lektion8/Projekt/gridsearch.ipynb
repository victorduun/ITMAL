# %%
# Grid search report generator
from time import time
import numpy as np

from sklearn import svm
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import datasets

from libitmal import dataloaders as itmaldataloaders # Needed for load of iris, moon and mnist

currmode="N/A" # GLOBAL var!

def SearchReport(model):

    def GetBestModelCTOR(model, best_params):
        def GetParams(best_params):
            ret_str=""
            for key in sorted(best_params):
                value = best_params[key]
                temp_str = "'" if str(type(value))=="<class 'str'>" else ""
                if len(ret_str)>0:
                    ret_str += ','
                ret_str += f'{key}={temp_str}{value}{temp_str}'
            return ret_str
        try:
            param_str = GetParams(best_params)
            return type(model).__name__ + '(' + param_str + ')'
        except:
            return "N/A(1)"

    print("\nBest model set found on train set:")
    print()
    print(f"\tbest parameters={model.best_params_}")
    print(f"\tbest '{model.scoring}' score={model.best_score_}")
    print(f"\tbest index={model.best_index_}")
    print()
    print(f"Best estimator CTOR:")
    print(f"\t{model.best_estimator_}")
    print()
    try:
        print(f"Grid scores ('{model.scoring}') on development set:")
        means = model.cv_results_['mean_test_score']
        stds  = model.cv_results_['std_test_score']
        i=0
        for mean, std, params in zip(means, stds, model.cv_results_['params']):
            print("\t[%2d]: %0.3f (+/-%0.03f) for %r" % (i, mean, std * 2, params))
            i += 1
    except:
        print("WARNING: the random search do not provide means/stds")

    global currmode
    assert "f1_micro"==str(model.scoring), f"come on, we need to fix the scoring to be able to compare model-fits! Your scoreing={str(model.scoring)}...remember to add scoring='f1_micro' to the search"
    return f"best: dat={currmode}, score={model.best_score_:0.5f}, model={GetBestModelCTOR(model.estimator,model.best_params_)}", model.best_estimator_

def ClassificationReport(model, X_test, y_test, target_names=None):
    assert X_test.shape[0]==y_test.shape[0]
    print("\nDetailed classification report:")
    print("\tThe model is trained on the full development set.")
    print("\tThe scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, model.predict(X_test)
    print(classification_report(y_true, y_pred, target_names))
    print()

def FullReport(model, X_test, y_test, t):
    print(f"SEARCH TIME: {t:0.2f} sec")
    beststr, bestmodel = SearchReport(model)
    ClassificationReport(model, X_test, y_test)
    print(f"CTOR for best model: {bestmodel}\n")
    print(f"{beststr}\n")
    return beststr, bestmodel

def LoadAndSetupData(mode, test_size=0.3):
    assert test_size>=0.0 and test_size<=1.0

    def ShapeToString(Z):
        n = Z.ndim
        s = "("
        for i in range(n):
            s += f"{Z.shape[i]:5d}"
            if i+1!=n:
                s += ";"
        return s+")"

    global currmode
    currmode=mode
    print(f"DATA: {currmode}..")

    if mode=='moon':
        X, y = itmaldataloaders.MOON_GetDataSet(n_samples=5000, noise=0.2)
        itmaldataloaders.MOON_Plot(X, y)
    elif mode=='mnist':
        X, y = itmaldataloaders.MNIST_GetDataSet(load_mode=2)
        if X.ndim==3:
            X=np.reshape(X, (X.shape[0], -1))
    elif mode=='iris':
        X, y = itmaldataloaders.IRIS_GetDataSet()
    else:
        raise ValueError(f"could not load data for that particular mode='{mode}', only 'moon'/'mnist'/'iris' supported")

    print(f'  org. data:  X.shape      ={ShapeToString(X)}, y.shape      ={ShapeToString(y)}')

    assert X.ndim==2
    assert X.shape[0]==y.shape[0]
    assert y.ndim==1 or (y.ndim==2 and y.shape[1]==0)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=0, shuffle=True
    )

    print(f'  train data: X_train.shape={ShapeToString(X_train)}, y_train.shape={ShapeToString(y_train)}')
    print(f'  test data:  X_test.shape ={ShapeToString(X_test)}, y_test.shape ={ShapeToString(y_test)}')
    print()

    return X_train, X_test, y_train, y_test

# %% [markdown]
# # Qa
# (Code review)
#
# The gridsearchCv model is constructed, and tuning parameters are parsed into the constructor.
# The gridsearch is then performed by calling the fit method on the grid object.
# The best model is printed with help from the FullReport function

# %% [markdown]
# # Qb

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = SGDClassifier(
)

tuning_parameters = {
    'penalty': ('l1', 'l2', 'elasticnet'),
    'l1_ratio': [0, 1], #Only used if 'elasticnet'
    'fit_intercept': [True, False],
    'max_iter': [100, 1000, 5000],
    'loss': ('hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'),
    'alpha': [0.1, 1, 10, 100, 1000],
    'epsilon': [0.1, 1, 10, 100, 1000],

}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model,
                          tuning_parameters,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1,
                          iid=True)
grid_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(grid_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 30.87 sec
#
# Best model set found on train set:
#
# 	best parameters={'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1'}
# 	best 'f1_micro' score=1.0
# 	best index=75
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.1, l1_ratio=1, loss='squared_hinge', penalty='l1')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.762 (+/-0.120) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'l1'}
# 	[ 1]: 0.867 (+/-0.203) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'l2'}
# 	[ 2]: 0.876 (+/-0.205) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[ 3]: 0.838 (+/-0.129) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1'}
# 	[ 4]: 0.714 (+/-0.085) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2'}
# 	[ 5]: 0.848 (+/-0.164) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[ 6]: 0.752 (+/-0.111) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'l1'}
# 	[ 7]: 0.867 (+/-0.236) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'l2'}
# 	[ 8]: 0.733 (+/-0.076) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[ 9]: 0.733 (+/-0.076) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 100, 'penalty': 'l1'}
# 	[10]: 0.800 (+/-0.126) for {'alpha': 0.1, 'epsilon': 0.1, 'fit_intercept': True, 'l1_ratio': 0, 'loss': 'log', 'max_iter':
: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 100, 'penalty': 'l2'}
# 	[4421]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4422]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4423]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4424]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4425]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4426]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4427]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'log', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4428]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'l1'}
# 	[4429]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'l2'}
# 	[4430]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4431]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4432]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4433]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4434]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4435]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4436]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4437]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'l1'}
# 	[4438]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'l2'}
# 	[4439]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4440]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4441]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4442]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4443]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4444]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4445]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4446]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'l1'}
# 	[4447]: 0.619 (+/-0.289) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'l2'}
# 	[4448]: 0.638 (+/-0.260) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4449]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4450]: 0.752 (+/-0.212) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4451]: 0.638 (+/-0.465) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4452]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4453]: 0.676 (+/-0.338) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4454]: 0.695 (+/-0.047) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 0, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4455]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'l1'}
# 	[4456]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'l2'}
# 	[4457]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4458]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4459]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4460]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4461]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4462]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4463]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'hinge', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4464]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 100, 'penalty': 'l1'}
# 	[4465]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 100, 'penalty': 'l2'}
# 	[4466]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4467]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4468]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4469]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4470]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4471]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4472]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'log', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4473]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'l1'}
# 	[4474]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'l2'}
# 	[4475]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4476]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4477]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4478]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4479]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4480]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4481]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'modified_huber', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4482]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'l1'}
# 	[4483]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'l2'}
# 	[4484]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4485]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4486]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4487]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4488]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4489]: 0.371 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4490]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'squared_hinge', 'max_iter': 5000, 'penalty': 'elasticnet'}
# 	[4491]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'l1'}
# 	[4492]: 0.638 (+/-0.379) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'l2'}
# 	[4493]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 100, 'penalty': 'elasticnet'}
# 	[4494]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'l1'}
# 	[4495]: 0.686 (+/-0.333) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'l2'}
# 	[4496]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 1000, 'penalty': 'elasticnet'}
# 	[4497]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'l1'}
# 	[4498]: 0.771 (+/-0.220) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'l2'}
# 	[4499]: 0.324 (+/-0.038) for {'alpha': 1000, 'epsilon': 1000, 'fit_intercept': False, 'l1_ratio': 1, 'loss': 'perceptron', 'max_iter': 5000, 'penalty': 'elasticnet'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.1, l1_ratio=1, loss='squared_hinge', penalty='l1')
#
# best: dat=iris, score=1.00000, model=SGDClassifier(alpha=0.1,epsilon=0.1,fit_intercept=True,l1_ratio=1,loss='squared_hinge',max_iter=1000,penalty='l1')
#
# OK(grid-search)
# c:\users\victo\aarhus universitet\test - dokumenter\elektronik\noter elektronik\elektronik 6. semester\itmal\itmal - exercises\venv\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# c:\users\victo\aarhus universitet\test - dokumenter\elektronik\noter elektronik\elektronik 6. semester\itmal\itmal - exercises\venv\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass labels=None as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %% [markdown]
# # Qc)
#  investigate the n_iter parameter...in code and write an conceptual explanation in text.

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'iris')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = SGDClassifier(
)

tuning_parameters = {
    'penalty': ('l1', 'l2', 'elasticnet'),
    'l1_ratio': [0, 1], #Only used if 'elasticnet'
    'fit_intercept': [True, False],
    'max_iter': [100, 1000, 5000],
    'loss': ('hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'),
    'alpha': [0.1, 1, 10, 100, 1000],
    'epsilon': [0.1, 1, 10, 100, 1000],
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
random_tuned = RandomizedSearchCV(model,
                          tuning_parameters,
                          n_iter=20,
                          random_state=42,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1,
                          iid=True)
random_tuned.fit(X_train, y_train)
t = time() - start

# Report result
b0, m0 = FullReport(random_tuned, X_test, y_test, t)
print('OK(grid-search)')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 0.35 sec
#
# Best model set found on train set:
#
# 	best parameters={'penalty': 'l1', 'max_iter': 5000, 'loss': 'modified_huber', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 10, 'alpha': 0.1}
# 	best 'f1_micro' score=0.9714285714285714
# 	best index=17
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.1, epsilon=10, fit_intercept=False, l1_ratio=0,
#               loss='modified_huber', max_iter=5000, penalty='l1')
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.838 (+/-0.143) for {'penalty': 'elasticnet', 'max_iter': 1000, 'loss': 'hinge', 'l1_ratio': 1, 'fit_intercept': False, 'epsilon': 1000, 'alpha': 0.1}
# 	[ 1]: 0.505 (+/-0.328) for {'penalty': 'l2', 'max_iter': 100, 'loss': 'perceptron', 'l1_ratio': 1, 'fit_intercept': False, 'epsilon': 0.1, 'alpha': 1000}
# 	[ 2]: 0.438 (+/-0.279) for {'penalty': 'elasticnet', 'max_iter': 1000, 'loss': 'squared_hinge', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 10, 'alpha': 100}
# 	[ 3]: 0.771 (+/-0.164) for {'penalty': 'l2', 'max_iter': 5000, 'loss': 'log', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 10, 'alpha': 0.1}
# 	[ 4]: 0.371 (+/-0.038) for {'penalty': 'l2', 'max_iter': 5000, 'loss': 'log', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 1000, 'alpha': 1000}
# 	[ 5]: 0.324 (+/-0.071) for {'penalty': 'l1', 'max_iter': 5000, 'loss': 'modified_huber', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 1000, 'alpha': 100}
# 	[ 6]: 0.324 (+/-0.038) for {'penalty': 'l1', 'max_iter': 1000, 'loss': 'modified_huber', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 10, 'alpha': 100}
# 	[ 7]: 0.333 (+/-0.060) for {'penalty': 'l1', 'max_iter': 1000, 'loss': 'perceptron', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 1, 'alpha': 100}
# 	[ 8]: 0.819 (+/-0.185) for {'penalty': 'l2', 'max_iter': 1000, 'loss': 'perceptron', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 0.1, 'alpha': 0.1}
# 	[ 9]: 0.695 (+/-0.047) for {'penalty': 'elasticnet', 'max_iter': 100, 'loss': 'modified_huber', 'l1_ratio': 1, 'fit_intercept': True, 'epsilon': 1000, 'alpha': 1}
# 	[10]: 0.848 (+/-0.229) for {'penalty': 'l2', 'max_iter': 1000, 'loss': 'hinge', 'l1_ratio': 1, 'fit_intercept': True, 'epsilon': 1000, 'alpha': 0.1}
# 	[11]: 0.352 (+/-0.076) for {'penalty': 'l1', 'max_iter': 5000, 'loss': 'hinge', 'l1_ratio': 1, 'fit_intercept': True, 'epsilon': 100, 'alpha': 10}
# 	[12]: 0.324 (+/-0.038) for {'penalty': 'l1', 'max_iter': 1000, 'loss': 'hinge', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 100, 'alpha': 10}
# 	[13]: 0.695 (+/-0.047) for {'penalty': 'elasticnet', 'max_iter': 1000, 'loss': 'log', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 1, 'alpha': 1}
# 	[14]: 0.371 (+/-0.038) for {'penalty': 'l2', 'max_iter': 100, 'loss': 'log', 'l1_ratio': 1, 'fit_intercept': False, 'epsilon': 100, 'alpha': 100}
# 	[15]: 0.371 (+/-0.038) for {'penalty': 'l2', 'max_iter': 1000, 'loss': 'modified_huber', 'l1_ratio': 1, 'fit_intercept': False, 'epsilon': 10, 'alpha': 1000}
# 	[16]: 0.343 (+/-0.071) for {'penalty': 'l1', 'max_iter': 5000, 'loss': 'modified_huber', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 1, 'alpha': 100}
# 	[17]: 0.971 (+/-0.076) for {'penalty': 'l1', 'max_iter': 5000, 'loss': 'modified_huber', 'l1_ratio': 0, 'fit_intercept': False, 'epsilon': 10, 'alpha': 0.1}
# 	[18]: 0.695 (+/-0.047) for {'penalty': 'elasticnet', 'max_iter': 100, 'loss': 'hinge', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 1, 'alpha': 1}
# 	[19]: 0.619 (+/-0.463) for {'penalty': 'elasticnet', 'max_iter': 100, 'loss': 'perceptron', 'l1_ratio': 0, 'fit_intercept': True, 'epsilon': 1000, 'alpha': 10}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.78      0.88        18
#            2       0.73      1.00      0.85        11
#
#     accuracy                           0.91        45
#    macro avg       0.91      0.93      0.91        45
# weighted avg       0.93      0.91      0.91        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.1, epsilon=10, fit_intercept=False, l1_ratio=0,
#               loss='modified_huber', max_iter=5000, penalty='l1')
#
# best: dat=iris, score=0.97143, model=SGDClassifier(alpha=0.1,epsilon=10,fit_intercept=False,l1_ratio=0,loss='modified_huber',max_iter=5000,penalty='l1')
#
# OK(grid-search)
# c:\users\victo\aarhus universitet\test - dokumenter\elektronik\noter elektronik\elektronik 6. semester\itmal\itmal - exercises\venv\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# c:\users\victo\aarhus universitet\test - dokumenter\elektronik\noter elektronik\elektronik 6. semester\itmal\itmal - exercises\venv\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass labels=None as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %% [markdown]
# # Qd)

# %%
from sklearn.linear_model import SGDClassifier

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData(
    'mnist')  # 'iris', 'moon', or 'mnist'

# Setup search parameters
model = SGDClassifier(
)

tuning_parameters = {
    'penalty': ('l1', 'l2', 'elasticnet'),
    'l1_ratio': [0, 1], #Only used if 'elasticnet'
    'fit_intercept': [True, False],
}

CV = 5
VERBOSE = 0

# Run GridSearchCV for the model
start = time()
random_tuned = RandomizedSearchCV(model,
                          tuning_parameters,
                          n_iter=2,
                          random_state=42,
                          cv=CV,
                          scoring='f1_micro',
                          verbose=VERBOSE,
                          n_jobs=-1,
                          iid=True)
random_tuned.fit(X_train, y_train)

t = time() - start

# Report result
b0, m0 = FullReport(random_tuned, X_test, y_test, t)
print('OK(grid-search)')
